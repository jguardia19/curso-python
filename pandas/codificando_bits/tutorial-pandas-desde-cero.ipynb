# %% [markdown]
# # TUTORIAL: PANDAS DESDE CERO
#
# En este tutorial veremos una introducción a la librería Pandas y a las herramientas que más comúnmente usaremos al momento de procesar y analizar datos tabulares en Python.
#
# Contenido:
#
# 1. Lectura de datos tabulares desde archivos CSV o Excel
# 2. DataFrames y Series
# 3. Métodos y atributos de uso más común en un DataFrame o Serie
# 4. Indexación
# 5. Manipulando el contenido de un DataFrame
# 6. Agrupaciones
# 7. Exportando un DataFrame

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\supernova dev 2\appdata\local\programs\python\python313\lib\site-packages (25.0.1)
# Collecting pip
#   Using cached pip-25.2-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.2-py3-none-any.whl (1.8 MB)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: C:\Users\Supernova dev 2\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\Supernova dev 2\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 1. Lectura de datos tabulares desde archivos CSV o Excel
#
# Podemos usar las funciones "read_csv" y "read_excel" de Pandas para leer estos tipos de archivo:

# %%
import pandas as pd

# Leer todas las columnas
df_csv = pd.read_csv("dataset_pandas.csv")
df_csv
# Out:
#                                                      id    edad  \
# 0                  6c7984c9-270d-4dee-b21e-8460ba65a683    75.0
# 1                  45b54530-317e-4c64-b718-597990ff6fd9    84.0
# 2                  87ef46d9-e9c8-4ba3-8965-5553b48ad2d9     NaN
# 3                  33267565-7115-4bec-9dc1-3e5057412d10    57.0
# 4                  3cddc250-e992-4a30-8097-f1422761b7be    59.0
# ...                                                 ...     ...
# 1000               02568917-9a13-4f6b-ba09-5d664e8069f6    34.0
# 1001               7ddaf233-2a46-429a-b4be-f8ff5917d299    47.0
# 1002               889d5238-aa0c-4717-b841-962d09eeca9c    76.0
# 1003               bacda779-4383-435c-a9d9-c8c8c5b28bd7    57.0
# 1004  Información tomada de: Servicio Nacional de Salud  2023.0
#
#                              email     genero                estado   IMC
# 0         salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1      haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 2                 ikynge2@cnbc.com   Femenino                Hawaii  26.7
# 3                jsnoad3@globo.com  Masculino            California  29.2
# 4          kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# ...                            ...        ...                   ...   ...
# 1000         tmoorhousero@live.com  Masculino             Louisiana  25.4
# 1001         sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002  mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003       sbussrr@fastcompany.com  Masculino              New York  24.5
# 1004                           NaN        NaN                   NaN   NaN
#
# [1005 rows x 6 columns]

# %%
# Leer sólo ciertas columnas
df_csv = pd.read_csv("dataset_pandas.csv",
                    usecols=['edad','email','estado'])
df_csv
# Out:
#         edad                         email                estado
# 0       75.0      salsobrook0@amazon.co.uk               Florida
# 1       84.0   haddenbrooke1@parallels.com              Illinois
# 2        NaN              ikynge2@cnbc.com                Hawaii
# 3       57.0             jsnoad3@globo.com            California
# 4       59.0       kstringer4@sakura.ne.jp                  Utah
# ...      ...                           ...                   ...
# 1000    34.0         tmoorhousero@live.com             Louisiana
# 1001    47.0         sarstingallrp@ibm.com  District of Columbia
# 1002    76.0  mmcgroartyrq@fastcompany.com               Florida
# 1003    57.0       sbussrr@fastcompany.com              New York
# 1004  2023.0                           NaN                   NaN
#
# [1005 rows x 3 columns]

# %%
# Leer todas las columnas pero NO leer
# el footer
df_csv = pd.read_csv("dataset_pandas.csv",
                    skipfooter=1)
df_csv
# Out:
# C:\Users\Supernova dev 2\AppData\Local\Temp\ipykernel_6900\1987647947.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df_csv = pd.read_csv("dataset_pandas.csv",
#                                         id  edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# ...                                    ...   ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
#                                   email     genero                estado   IMC
# 0              salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1           haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 2                      ikynge2@cnbc.com   Femenino                Hawaii  26.7
# 3                     jsnoad3@globo.com  Masculino            California  29.2
# 4               kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# ...                                 ...        ...                   ...   ...
# 999   ldelavaletteparisotrn@booking.com   Femenino            California  25.7
# 1000              tmoorhousero@live.com  Masculino             Louisiana  25.4
# 1001              sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002       mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003            sbussrr@fastcompany.com  Masculino              New York  24.5
#
# [1004 rows x 6 columns]

# %%
# Leer excel (por defecto se lee la primera hoja)
df_xls = pd.read_excel('dataset_pandas.xlsx', engine='openpyxl')
df_xls
# Out:
#                                                      id  edad  \
# 0                  6dbfd2dd-f136-4fb4-855e-44756fc08298  39.0
# 1                  b60c7351-f1ec-43a8-a29a-cb8d0ca48d16  45.0
# 2                  6523676e-4416-4d5a-9c99-e9ca5dcbb3fa  77.0
# 3                  d36674c5-37bc-4210-a0b6-943d286e0090  43.0
# 4                  67d2e157-332f-42df-8058-5bfa021a1cfc  41.0
# ...                                                 ...   ...
# 1001               2e2f5a19-076a-4cf5-b733-6831aee8d352  22.0
# 1002               567cf0fb-5ab6-4ff1-9259-dcb336a47bf2  42.0
# 1003                                                NaN   NaN
# 1004                                                NaN   NaN
# 1005  Información tomada de: Servicio Nacional de Sa...   NaN
#
#                           email     genero                estado   IMC
# 0      ahaygreen0@shinystat.com   Femenino                Hawaii  22.1
# 1             apeskett1@hud.gov  Masculino                Kansas  25.2
# 2             edrohan2@dell.com  Masculino  District of Columbia  18.7
# 3              gdoyley3@mit.edu   Femenino              Michigan  29.0
# 4             mscullard4@ft.com   Femenino                   NaN  24.7
# ...                         ...        ...                   ...   ...
# 1001  foutridgerq@discovery.com   Femenino                 Idaho  21.8
# 1002    igingellrr@edublogs.org  Masculino              Michigan  29.6
# 1003                        NaN        NaN                   NaN   NaN
# 1004                        NaN        NaN                   NaN   NaN
# 1005                        NaN        NaN                   NaN   NaN
#
# [1006 rows x 6 columns]

# %%
# Leer excel (por defecto se lee la primera hoja)
df_xls = pd.read_excel('dataset_pandas.xlsx',
                    sheet_name='mini_tabla')
df_xls
# Out:
#                                       id  edad  \
# 0   6dbfd2dd-f136-4fb4-855e-44756fc08298    39
# 1   b60c7351-f1ec-43a8-a29a-cb8d0ca48d16    45
# 2   6523676e-4416-4d5a-9c99-e9ca5dcbb3fa    77
# 3   d36674c5-37bc-4210-a0b6-943d286e0090    43
# 4   67d2e157-332f-42df-8058-5bfa021a1cfc    41
# 5   73f80288-6320-4e09-8011-834edc593223    54
# 6   f085c700-3b4c-48f9-9331-2f8595c45952    58
# 7   6f2a9306-2f29-492f-b5a1-6a05fe5b000a    83
# 8   6973c416-b77f-4e8e-ab8a-f9bfdd64e8a5    78
# 9   d3d25b91-7bcb-4f7b-9c6a-ed6e2154ec97    78
# 10  6548e215-223f-42e7-aefb-3b49fc1f7a1f    47
#
#                                email     genero
# 0           ahaygreen0@shinystat.com   Femenino
# 1                  apeskett1@hud.gov  Masculino
# 2                  edrohan2@dell.com  Masculino
# 3                   gdoyley3@mit.edu   Femenino
# 4                  mscullard4@ft.com   Femenino
# 5                 gduncombe5@com.com   Femenino
# 6            lcromett6@economist.com  Masculino
# 7           gmcorkil7@shareasale.com  Masculino
# 8          ealeshkov8@craigslist.org  Masculino
# 9                asorro9@smugmug.com   Femenino
# 10  ahawkeswooda@theglobeandmail.com  Masculino

# %%
# Leer sólo ciertas columnas de la primera hoja
df_xls = pd.read_excel('dataset_pandas.xlsx',
                       usecols=['id','edad','IMC'])
df_xls
# Out:
#                                                      id  edad   IMC
# 0                  6dbfd2dd-f136-4fb4-855e-44756fc08298  39.0  22.1
# 1                  b60c7351-f1ec-43a8-a29a-cb8d0ca48d16  45.0  25.2
# 2                  6523676e-4416-4d5a-9c99-e9ca5dcbb3fa  77.0  18.7
# 3                  d36674c5-37bc-4210-a0b6-943d286e0090  43.0  29.0
# 4                  67d2e157-332f-42df-8058-5bfa021a1cfc  41.0  24.7
# ...                                                 ...   ...   ...
# 1001               2e2f5a19-076a-4cf5-b733-6831aee8d352  22.0  21.8
# 1002               567cf0fb-5ab6-4ff1-9259-dcb336a47bf2  42.0  29.6
# 1003                                                NaN   NaN   NaN
# 1004                                                NaN   NaN   NaN
# 1005  Información tomada de: Servicio Nacional de Sa...   NaN   NaN
#
# [1006 rows x 3 columns]

# %%
# Leer todas las columnas y todas las filas
# exceptuando las tres últimas
df_xls = pd.read_excel('dataset_pandas.xlsx',
                skipfooter=3)
df_xls
# Out:
#                                         id  edad                      email  \
# 0     6dbfd2dd-f136-4fb4-855e-44756fc08298  39.0   ahaygreen0@shinystat.com
# 1     b60c7351-f1ec-43a8-a29a-cb8d0ca48d16  45.0          apeskett1@hud.gov
# 2     6523676e-4416-4d5a-9c99-e9ca5dcbb3fa  77.0          edrohan2@dell.com
# 3     d36674c5-37bc-4210-a0b6-943d286e0090  43.0           gdoyley3@mit.edu
# 4     67d2e157-332f-42df-8058-5bfa021a1cfc  41.0          mscullard4@ft.com
# ...                                    ...   ...                        ...
# 998   be107c02-7e02-45e7-b0e6-8a27e5fe701c  65.0     ahuskern@discovery.com
# 999   809915b9-d6d3-4e9d-87cf-27fa8feab31c  50.0           emeehanro@goo.gl
# 1000  32381972-b052-48dc-bf53-29e527cb0eec  27.0         jmahareyrp@free.fr
# 1001  2e2f5a19-076a-4cf5-b733-6831aee8d352  22.0  foutridgerq@discovery.com
# 1002  567cf0fb-5ab6-4ff1-9259-dcb336a47bf2  42.0    igingellrr@edublogs.org
#
#          genero                estado   IMC
# 0      Femenino                Hawaii  22.1
# 1     Masculino                Kansas  25.2
# 2     Masculino  District of Columbia  18.7
# 3      Femenino              Michigan  29.0
# 4      Femenino                   NaN  24.7
# ...         ...                   ...   ...
# 998   Masculino               Indiana  24.5
# 999    Femenino            California  18.7
# 1000   Femenino                   NaN  28.0
# 1001   Femenino                 Idaho  21.8
# 1002  Masculino              Michigan  29.6
#
# [1003 rows x 6 columns]

# %% [markdown]
# ## 2. DataFrames y Series
#
# Los DataFrames y las Series son los dos principales tipos de datos en Pandas.
#
# En esencia:
#
# - Un DataFrame es un arreglo 2D (tabla)
# - Una Serie es un arreglo 1D (columna)

# %%
type(df_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
columna = df_csv['edad']
columna
# Out:
# 0       75.0
# 1       84.0
# 2        NaN
# 3       57.0
# 4       59.0
#         ...
# 999     49.0
# 1000    34.0
# 1001    47.0
# 1002    76.0
# 1003    57.0
# Name: edad, Length: 1004, dtype: float64

# %%
type(columna)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Todo DataFrame y Serie tiene una serie de **métodos** y **atributos** a los cuales podemos acceder usando esta sintaxis:

# %% [markdown]
# ## 3. Métodos y atributos de uso más común en un DataFrame o Serie
#
# Los DataFrames y las Series son tipos de objetos y por tanto, en el lenguaje de la programación orientada a objetos, tienen asociados unos métodos y unos atributos.
#
# Veamos los métodos y atributos de uso más común:
#
# - "info()": nos permite ver un resumen de las principales características del arreglo (número de registros, nombres de las columnas, tipos de dato de cada columna, entre otras):

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      968 non-null    object
#  1   edad    931 non-null    float64
#  2   email   1004 non-null   object
#  3   genero  1004 non-null   object
#  4   estado  919 non-null    object
#  5   IMC     988 non-null    float64
# dtypes: float64(2), object(4)
# memory usage: 47.2+ KB

# %% [markdown]
# - "shape": nos permite ver el tamaño del arreglo (número de filas x número de columnas):

# %%
df_csv.shape
# Out:
# (1004, 6)

# %% [markdown]
# - "columns" e "index" nos permite acceder a los nombres de cada columna (en el caso de los DataFrames) y al índice del arreglo:

# %%
df_csv.columns
# Out:
# Index(['id', 'edad', 'email', 'genero', 'estado', 'IMC'], dtype='object')

# %%
df_csv.index
# Out:
# RangeIndex(start=0, stop=1004, step=1)

# %% [markdown]
# - "to_numpy()": nos permite extraer el contenido del arreglo en formato NumPy (eliminando el índice y los nombres de las columnas - en el caso de los DataFrames -):

# %%
df_csv.to_numpy()
# Out:
# array([['6c7984c9-270d-4dee-b21e-8460ba65a683', 75.0,
#         'salsobrook0@amazon.co.uk', 'Masculino', 'Florida', 26.7],
#        ['45b54530-317e-4c64-b718-597990ff6fd9', 84.0,
#         'haddenbrooke1@parallels.com', 'Masculino', 'Illinois', 30.6],
#        ['87ef46d9-e9c8-4ba3-8965-5553b48ad2d9', nan, 'ikynge2@cnbc.com',
#         'Femenino', 'Hawaii', 26.7],
#        ...,
#        ['7ddaf233-2a46-429a-b4be-f8ff5917d299', 47.0,
#         'sarstingallrp@ibm.com', 'Masculino', 'District of Columbia',
#         26.4],
#        ['889d5238-aa0c-4717-b841-962d09eeca9c', 76.0,
#         'mmcgroartyrq@fastcompany.com', 'Femenino', 'Florida', 18.3],
#        ['bacda779-4383-435c-a9d9-c8c8c5b28bd7', 57.0,
#         'sbussrr@fastcompany.com', 'Masculino', 'New York', 24.5]],
#       dtype=object)

# %% [markdown]
# - "head(N)" y "tail(N)": nos permite ver los primeros/últimos "N" registros de la tabla. Si no agregamos argumento al método nos retorna por defecto las primeras/últimas 5 filas:

# %%
df_csv.head(10)
# Out:
#                                      id  edad                        email  \
# 0  6c7984c9-270d-4dee-b21e-8460ba65a683  75.0     salsobrook0@amazon.co.uk
# 1  45b54530-317e-4c64-b718-597990ff6fd9  84.0  haddenbrooke1@parallels.com
# 2  87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN             ikynge2@cnbc.com
# 3  33267565-7115-4bec-9dc1-3e5057412d10  57.0            jsnoad3@globo.com
# 4  3cddc250-e992-4a30-8097-f1422761b7be  59.0      kstringer4@sakura.ne.jp
# 5  08f55fb0-85d1-416c-adc8-70a452e1a415  39.0             ahagger5@icq.com
# 6  4fbe704c-e876-4236-b42a-24b551a56af6  80.0      tleversuch6@mozilla.com
# 7  8fec9c7d-4207-4a5f-925e-746231185924  44.0       shablot7@reference.com
# 8  a48b463e-675d-421c-b0b1-e21505232f10  64.0    dwiddall8@list-manage.com
# 9  6bb1103b-fbfc-474c-b2aa-19bbad448f98  50.0        kbattie9@symantec.com
#
#       genero      estado   IMC
# 0  Masculino     Florida  26.7
# 1  Masculino    Illinois  30.6
# 2   Femenino      Hawaii  26.7
# 3  Masculino  California  29.2
# 4   Femenino        Utah  27.5
# 5   Femenino       Texas  29.7
# 6   Femenino         NaN  22.3
# 7   Femenino       Texas  21.3
# 8  Masculino    Virginia  20.3
# 9  Masculino    Illinois  23.2

# %% [markdown]
# - "describe()": un método muy utilizado al hacer análisis exploratorio de datos. Permite generar un resumen de las principales características de las variables tanto numéricas como categóricas:

# %%
# "describe" sin argumentos: por defecto genera un resumen
# únicamente de las variables numéricas
df_csv.describe()
# Out:
#              edad         IMC
# count  931.000000  988.000000
# mean    52.053706   24.941700
# std     19.991378    3.997781
# min     18.000000   18.000000
# 25%     35.500000   21.400000
# 50%     53.000000   24.750000
# 75%     69.000000   28.400000
# max     87.000000   32.000000

# %%
# "describe" con argumento "include=[object]" para generar
# resumen únicamente de las variables categóricas
df_csv.describe(include=[object])
# Out:
#                                           id               email    genero  \
# count                                    968                1004      1004
# unique                                   964                1000         2
# top     e3289ac1-9930-487e-b735-8037f91b207e  ecleator1s@nps.gov  Femenino
# freq                                       2                   2       521
#
#        estado
# count     919
# unique     47
# top     Texas
# freq      103

# %% [markdown]
# - "drop_duplicates()": permite eliminar registros (filas) duplicadas preservando únicamente la primera aparición. Muy útil en la limpieza de datos

# %%
df_sin_dup = df_csv.drop_duplicates()
print('DataFrame con duplicados: ', df_csv.shape)
print('DataFrame sin duplicados: ', df_sin_dup.shape)
# Out:
# DataFrame con duplicados:  (1004, 6)
# DataFrame sin duplicados:  (1000, 6)

# %% [markdown]
# - "dropna()": permite buscar las filas que contengan celdas vacías (tipo "NaN" o *not a number*) y eliminarlas. Muy útil en la limpieza de datos:

# %%
df_sin_na = df_sin_dup.dropna()
print('DataFrame con duplicados: ', df_csv.shape)
print('DataFrame sin duplicados: ', df_sin_dup.shape)
print('DataFrame sin duplicados y sin NaN: ', df_sin_na.shape)
# Out:
# DataFrame con duplicados:  (1004, 6)
# DataFrame sin duplicados:  (1000, 6)
# DataFrame sin duplicados y sin NaN:  (800, 6)

# %% [markdown]
# - "isna()": permite detectar en qué ubicaciones se encuentran las celdas vacías (tipo "NaN"):

# %%
df_csv.isna()
# Out:
#          id   edad  email  genero  estado    IMC
# 0     False  False  False   False   False  False
# 1     False  False  False   False   False  False
# 2     False   True  False   False   False  False
# 3     False  False  False   False   False  False
# 4     False  False  False   False   False  False
# ...     ...    ...    ...     ...     ...    ...
# 999   False  False  False   False   False  False
# 1000  False  False  False   False   False  False
# 1001  False  False  False   False   False  False
# 1002  False  False  False   False   False  False
# 1003  False  False  False   False   False  False
#
# [1004 rows x 6 columns]

# %% [markdown]
# Y podemos combinar lo anterior con el método "sum()" para determinar la cantidad de datos faltantes en cada columna:

# %%
df_csv.isna().sum()
# Out:
# id        36
# edad      73
# email      0
# genero     0
# estado    85
# IMC       16
# dtype: int64

# %% [markdown]
# ## 4. Indexación
#
# La indexación nos permite acceder o extraer porciones de un *DataFrame* o de una Serie y es una operación muy pero muy común al momento de procesar y analizar datos tabulares.
#
# Veamos las principales formas de realizar esta indexación.

# %% [markdown]
# ### 4.1. Extracción de una o múltiples columnas
#
# En este caso usamos la sintaxis `df['nombre_columna']` o `df[[listado_de_columnas]]`.
#
# Por ejemplo, extraigamos únicamente la columna género:

# %%
df_csv['genero']
# Out:
# 0       Masculino
# 1       Masculino
# 2        Femenino
# 3       Masculino
# 4        Femenino
#           ...
# 999      Femenino
# 1000    Masculino
# 1001    Masculino
# 1002     Femenino
# 1003    Masculino
# Name: genero, Length: 1004, dtype: object

# %% [markdown]
# O extraigamos las columnas "genero" e "email":

# %%
df_csv[['genero', 'email']]
# Out:
#          genero                              email
# 0     Masculino           salsobrook0@amazon.co.uk
# 1     Masculino        haddenbrooke1@parallels.com
# 2      Femenino                   ikynge2@cnbc.com
# 3     Masculino                  jsnoad3@globo.com
# 4      Femenino            kstringer4@sakura.ne.jp
# ...         ...                                ...
# 999    Femenino  ldelavaletteparisotrn@booking.com
# 1000  Masculino              tmoorhousero@live.com
# 1001  Masculino              sarstingallrp@ibm.com
# 1002   Femenino       mmcgroartyrq@fastcompany.com
# 1003  Masculino            sbussrr@fastcompany.com
#
# [1004 rows x 2 columns]

# %% [markdown]
# ### 4.2. Extraer un rango de filas
#
# El método "iloc()": nos permite extraer parte de las filas del *DataFrame* o Serie.
#
# Por ejemplo, para extraer las primeras 10 filas escribimos:

# %%
df_csv.iloc[0:10,:] # También podemos escribir [:10]
# Out:
#                                      id  edad                        email  \
# 0  6c7984c9-270d-4dee-b21e-8460ba65a683  75.0     salsobrook0@amazon.co.uk
# 1  45b54530-317e-4c64-b718-597990ff6fd9  84.0  haddenbrooke1@parallels.com
# 2  87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN             ikynge2@cnbc.com
# 3  33267565-7115-4bec-9dc1-3e5057412d10  57.0            jsnoad3@globo.com
# 4  3cddc250-e992-4a30-8097-f1422761b7be  59.0      kstringer4@sakura.ne.jp
# 5  08f55fb0-85d1-416c-adc8-70a452e1a415  39.0             ahagger5@icq.com
# 6  4fbe704c-e876-4236-b42a-24b551a56af6  80.0      tleversuch6@mozilla.com
# 7  8fec9c7d-4207-4a5f-925e-746231185924  44.0       shablot7@reference.com
# 8  a48b463e-675d-421c-b0b1-e21505232f10  64.0    dwiddall8@list-manage.com
# 9  6bb1103b-fbfc-474c-b2aa-19bbad448f98  50.0        kbattie9@symantec.com
#
#       genero      estado   IMC
# 0  Masculino     Florida  26.7
# 1  Masculino    Illinois  30.6
# 2   Femenino      Hawaii  26.7
# 3  Masculino  California  29.2
# 4   Femenino        Utah  27.5
# 5   Femenino       Texas  29.7
# 6   Femenino         NaN  22.3
# 7   Femenino       Texas  21.3
# 8  Masculino    Virginia  20.3
# 9  Masculino    Illinois  23.2

# %% [markdown]
# El uso de ":" como segundo argumento indica que tomaremos todas las columnas.
#
# Si queremos extraer las primeras 10 filas pero únicamente las columnas desde la "edad" (índice 1) a "género" (índice 3) escribimos:

# %%
df_csv.iloc[:10,1:4]
# Out:
#    edad                        email     genero
# 0  75.0     salsobrook0@amazon.co.uk  Masculino
# 1  84.0  haddenbrooke1@parallels.com  Masculino
# 2   NaN             ikynge2@cnbc.com   Femenino
# 3  57.0            jsnoad3@globo.com  Masculino
# 4  59.0      kstringer4@sakura.ne.jp   Femenino
# 5  39.0             ahagger5@icq.com   Femenino
# 6  80.0      tleversuch6@mozilla.com   Femenino
# 7  44.0       shablot7@reference.com   Femenino
# 8  64.0    dwiddall8@list-manage.com  Masculino
# 9  50.0        kbattie9@symantec.com  Masculino

# %% [markdown]
# ### 4.3. Filtrando filas y columnas
#
# Y podemos hacer uso de **condicionales** para extraer porciones de un *DataFrame*.
#
# Por ejemplo, extraigamos únicamente las personas con edades mayores a 35 años. En este caso podemos usar el método "loc":

# %%
df_csv.loc[df_csv['edad']>35]
# Out:
#                                         id  edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# 5     08f55fb0-85d1-416c-adc8-70a452e1a415  39.0
# ...                                    ...   ...
# 998   9f986af0-10de-4256-afd3-543ece7a8cd1  42.0
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
#                                   email     genero                estado   IMC
# 0              salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1           haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 3                     jsnoad3@globo.com  Masculino            California  29.2
# 4               kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# 5                      ahagger5@icq.com   Femenino                 Texas  29.7
# ...                                 ...        ...                   ...   ...
# 998              hmulgrewrm@mozilla.org  Masculino              Colorado  19.8
# 999   ldelavaletteparisotrn@booking.com   Femenino            California  25.7
# 1001              sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002       mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003            sbussrr@fastcompany.com  Masculino              New York  24.5
#
# [698 rows x 6 columns]

# %% [markdown]
# Y en el argumento de "loc" también podemos incluir las columnas a extraer. Por ejemplo, usemos el condicional anterior y extraigamos además las columnas "email" e "IMC":

# %%
df_csv.loc[df_csv['edad']>35, ['email', 'IMC']]
# Out:
#                                   email   IMC
# 0              salsobrook0@amazon.co.uk  26.7
# 1           haddenbrooke1@parallels.com  30.6
# 3                     jsnoad3@globo.com  29.2
# 4               kstringer4@sakura.ne.jp  27.5
# 5                      ahagger5@icq.com  29.7
# ...                                 ...   ...
# 998              hmulgrewrm@mozilla.org  19.8
# 999   ldelavaletteparisotrn@booking.com  25.7
# 1001              sarstingallrp@ibm.com  26.4
# 1002       mmcgroartyrq@fastcompany.com  18.3
# 1003            sbussrr@fastcompany.com  24.5
#
# [698 rows x 2 columns]

# %% [markdown]
# ## 5. Manipulando el contenido de un DataFrame
#
# Y podemos usar varias herramientas que nos permiten generar nuevas tablas manipulando el contenido de la tabla (DataFrame) original.

# %% [markdown]
# ### 5.1. Ordenamiento de DataFrames
#
# Podemos **ordenar** las filas de una tabla con respecto a un cierto criterio.
#
# Por ejemplo, ordenemos las filas usando como criterio la edad (de menor a mayor):

# %%
df_csv.sort_values(by='edad')
# Out:
#                                        id  edad  \
# 834                                   NaN  18.0
# 710  840882a0-b681-4d1a-b65f-87319811d279  18.0
# 814  a7344bea-af3d-4bf5-91a6-0912beaf499d  18.0
# 844  4294de71-bdf5-4ac7-9ec0-bf85c33e5069  18.0
# 510  7711115b-8da5-4e0d-b57e-8a667f00b9d2  18.0
# ..                                    ...   ...
# 919  34cb101d-198f-4e65-a69b-647b677816f0   NaN
# 955  46d7f704-572f-4a01-9aec-636541986e14   NaN
# 969  6e8d2893-1d62-4769-becf-774f79c51669   NaN
# 975  8b9f8ede-7cbf-48e6-9959-ef200e9053df   NaN
# 988  7492625a-930b-4eb2-b12c-233c476477a2   NaN
#
#                              email     genero         estado   IMC
# 834               csybryn2@com.com   Femenino           Ohio  21.3
# 710          cmcnamarajm@google.cn  Masculino  Massachusetts  25.7
# 814         kklimschakmi@opera.com  Masculino            NaN  31.9
# 844       plawrancenc@bandcamp.com   Femenino        Georgia  26.5
# 510           farnalde2@boston.com   Femenino          Texas  21.2
# ..                             ...        ...            ...   ...
# 919  manderbruggepf@thetimes.co.uk   Femenino   Pennsylvania  25.2
# 955    tshelbourneqf@indiegogo.com   Femenino           Ohio  22.2
# 969               etroyesqt@i2i.jp   Femenino      Louisiana  29.0
# 975          aandrezqz@godaddy.com   Femenino       Missouri  29.5
# 988  dgidleyrc@acquirethisname.com  Masculino       New York  24.9
#
# [1004 rows x 6 columns]

# %% [markdown]
# Y para ordenar de manera descendente lo podemos hacer usando el argumento "ascending = False":

# %%
df_csv.sort_values(by='edad', ascending=False)
# Out:
#                                        id  edad  \
# 479  273ff3a1-1822-42e1-82b8-005d7f55b789  87.0
# 911  81533bf9-26b1-4116-9cb5-36032ade0276  87.0
# 564  b49eddf1-83bf-49d6-91c7-bcaf95cd1fb0  87.0
# 726  db990f12-c1ab-40a6-a35b-e5d8d71624eb  87.0
# 982  582efee3-d859-4b60-88f0-bdbfc5f50594  87.0
# ..                                    ...   ...
# 919  34cb101d-198f-4e65-a69b-647b677816f0   NaN
# 955  46d7f704-572f-4a01-9aec-636541986e14   NaN
# 969  6e8d2893-1d62-4769-becf-774f79c51669   NaN
# 975  8b9f8ede-7cbf-48e6-9959-ef200e9053df   NaN
# 988  7492625a-930b-4eb2-b12c-233c476477a2   NaN
#
#                              email     genero        estado   IMC
# 479      lspellesyd7@aboutads.info   Femenino         Texas  24.3
# 911             dhoweyp7@patch.com   Femenino         Texas  31.3
# 564           elayingfk@nsw.gov.au   Femenino          Ohio  27.5
# 726        mreinbeckk2@auda.org.au  Masculino    California  30.8
# 982    svanwaadenburgr6@discuz.net  Masculino           NaN  30.4
# ..                             ...        ...           ...   ...
# 919  manderbruggepf@thetimes.co.uk   Femenino  Pennsylvania  25.2
# 955    tshelbourneqf@indiegogo.com   Femenino          Ohio  22.2
# 969               etroyesqt@i2i.jp   Femenino     Louisiana  29.0
# 975          aandrezqz@godaddy.com   Femenino      Missouri  29.5
# 988  dgidleyrc@acquirethisname.com  Masculino      New York  24.9
#
# [1004 rows x 6 columns]

# %% [markdown]
# Y podemos usar múltiples criterios de ordenamiento. Por ejemplo ordenemos de manera ascendente por edad y por IMC:

# %%
df_csv.sort_values(by=['edad', 'IMC'])
# Out:
#                                        id  edad  \
# 327  5656e1ad-1cdd-4639-ac74-3ac91beb9a3c  18.0
# 510  7711115b-8da5-4e0d-b57e-8a667f00b9d2  18.0
# 834                                   NaN  18.0
# 963  8b859f97-821e-4632-a120-f589fff82264  18.0
# 13                                    NaN  18.0
# ..                                    ...   ...
# 195  4c82ec76-bbe5-4d16-82eb-99bed20fb778   NaN
# 358  c9ec5bf5-a967-4b7a-8aad-84a8e533e923   NaN
# 185  0440e937-7913-4410-a3c6-69457b807857   NaN
# 722  1b2caa83-db28-45d9-a5cf-b9932bbbf2a8   NaN
# 905  db36bef3-823f-4ab5-9abd-3ca44f59dc93   NaN
#
#                              email     genero                estado   IMC
# 327          bdonaher8z@census.gov   Femenino                 Texas  18.8
# 510           farnalde2@boston.com   Femenino                 Texas  21.2
# 834               csybryn2@com.com   Femenino                  Ohio  21.3
# 963           stimlettqn@zdnet.com   Femenino              Colorado  22.7
# 13        jodcroftd@friendfeed.com  Masculino            California  23.0
# ..                             ...        ...                   ...   ...
# 195       mruoff5c@liveinternet.ru  Masculino  District of Columbia  31.4
# 358     gbennellick9u@geocities.jp  Masculino               Georgia  31.7
# 185  pfranssen53@sciencedirect.com  Masculino                Kansas  31.8
# 722          lmcallisterjy@loc.gov   Femenino              Virginia  31.8
# 905         ogockelerp1@nsw.gov.au   Femenino               Alabama  31.8
#
# [1004 rows x 6 columns]

# %% [markdown]
# Y esta lógica también se puede aplicar para ordenar alfabéticamente usando como criterio variables categóricas.
#
# Por ejemplo, ordenemos el DataFrame por estados alfabéticamente de la A a la Z:

# %%
df_csv.sort_values(by=['estado'], ascending=False)
# Out:
#                                        id  edad  \
# 766  83a99c98-3a77-4a9f-b310-594543d1b595   NaN
# 813  20ffad82-47d4-4110-8165-fd5801d9217a  43.0
# 174  5ac34cf5-62d6-4c0f-a97f-ece875cd3fa6  62.0
# 771  20bf01bd-841e-4fd7-a743-828ec2123d0f   NaN
# 98   e29df9ff-6fd2-41eb-b45a-a743371a2e34  26.0
# ..                                    ...   ...
# 959  a7bba9de-37df-43b4-a977-6573a3272ce6  46.0
# 966  a572af69-150f-4f4e-b8a5-ae838e6b8159  62.0
# 976  3067eb55-af3c-4bb1-adc0-6d113ce5993a  22.0
# 982  582efee3-d859-4b60-88f0-bdbfc5f50594  87.0
# 985  5f62c9f0-d830-419f-b77f-d9b235d8c1ad  64.0
#
#                                 email     genero     estado   IMC
# 766       ddochartyl6@sourceforge.net  Masculino  Wisconsin  24.5
# 813  dwhittockmh@networksolutions.com  Masculino  Wisconsin  22.5
# 174                 ljasiak4s@fda.gov   Femenino  Wisconsin  26.6
# 771              mkenwortheylb@ft.com   Femenino  Wisconsin  19.1
# 98          azavittieri2o@reuters.com   Femenino  Wisconsin   NaN
# ..                                ...        ...        ...   ...
# 959             sfennyqj@examiner.com   Femenino        NaN  28.7
# 966                rboulderqq@fda.gov   Femenino        NaN  31.2
# 976            lminchintonr0@about.me  Masculino        NaN  25.4
# 982       svanwaadenburgr6@discuz.net  Masculino        NaN  30.4
# 985           stwycrossr9@answers.com   Femenino        NaN  19.3
#
# [1004 rows x 6 columns]

# %% [markdown]
# ### 5.2. Renombrar columnas
#
# Podemos cambiar el nombre de una o varias columnas usando el método "rename".
#
# Como argumento de este método usamos un diccionario que contendrá el nombre original y el nuevo nombre para cada columna que queramos renombrar:

# %%
df_csv.rename(columns={'edad':'Edad', 'genero':'género'})
# Out:
#                                         id  Edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# ...                                    ...   ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
#                                   email     género                estado   IMC
# 0              salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1           haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 2                      ikynge2@cnbc.com   Femenino                Hawaii  26.7
# 3                     jsnoad3@globo.com  Masculino            California  29.2
# 4               kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# ...                                 ...        ...                   ...   ...
# 999   ldelavaletteparisotrn@booking.com   Femenino            California  25.7
# 1000              tmoorhousero@live.com  Masculino             Louisiana  25.4
# 1001              sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002       mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003            sbussrr@fastcompany.com  Masculino              New York  24.5
#
# [1004 rows x 6 columns]

# %%
df_csv
# Out:
#                                         id  edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# ...                                    ...   ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
#                                   email     genero                estado   IMC
# 0              salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1           haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 2                      ikynge2@cnbc.com   Femenino                Hawaii  26.7
# 3                     jsnoad3@globo.com  Masculino            California  29.2
# 4               kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# ...                                 ...        ...                   ...   ...
# 999   ldelavaletteparisotrn@booking.com   Femenino            California  25.7
# 1000              tmoorhousero@live.com  Masculino             Louisiana  25.4
# 1001              sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002       mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003            sbussrr@fastcompany.com  Masculino              New York  24.5
#
# [1004 rows x 6 columns]

# %% [markdown]
# ### 5.3. Eliminar columnas
#
# En este caso podemos usar "drop" en donde especificaremos la(s) columna(s) a eliminar:

# %%
# Eliminar la columna e-mail
df_csv.drop(columns=['email'])
# Out:
#                                         id  edad     genero  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0  Masculino
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0  Masculino
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN   Femenino
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0  Masculino
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0   Femenino
# ...                                    ...   ...        ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0   Femenino
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0  Masculino
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0  Masculino
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0   Femenino
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0  Masculino
#
#                     estado   IMC
# 0                  Florida  26.7
# 1                 Illinois  30.6
# 2                   Hawaii  26.7
# 3               California  29.2
# 4                     Utah  27.5
# ...                    ...   ...
# 999             California  25.7
# 1000             Louisiana  25.4
# 1001  District of Columbia  26.4
# 1002               Florida  18.3
# 1003              New York  24.5
#
# [1004 rows x 5 columns]

# %% [markdown]
# A pesar de que la tabla impresa en pantalla no contiene la columna "email", realmente **este cambio no persiste**.
#
# Esto quiere decir que si imprimimos nuevamente "df_csv" veremos la tabla original:

# %%
df_csv
# Out:
#                                         id  edad  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0
# ...                                    ...   ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0
#
#                                   email     genero                estado   IMC
# 0              salsobrook0@amazon.co.uk  Masculino               Florida  26.7
# 1           haddenbrooke1@parallels.com  Masculino              Illinois  30.6
# 2                      ikynge2@cnbc.com   Femenino                Hawaii  26.7
# 3                     jsnoad3@globo.com  Masculino            California  29.2
# 4               kstringer4@sakura.ne.jp   Femenino                  Utah  27.5
# ...                                 ...        ...                   ...   ...
# 999   ldelavaletteparisotrn@booking.com   Femenino            California  25.7
# 1000              tmoorhousero@live.com  Masculino             Louisiana  25.4
# 1001              sarstingallrp@ibm.com  Masculino  District of Columbia  26.4
# 1002       mmcgroartyrq@fastcompany.com   Femenino               Florida  18.3
# 1003            sbussrr@fastcompany.com  Masculino              New York  24.5
#
# [1004 rows x 6 columns]

# %% [markdown]
# Siempre que apliquemos cualquier operación a un DataFrame y queramos preservar los cambios en el mismo DataFrame debemos usar "inplace=True":

# %%
# Eliminar la columna "email" y sobre-escribir los cambios
df_csv.drop(columns=['email'], inplace=True)

# %% [markdown]
# Y si ahora imprimimos "df_csv" veremos que se preservan los cambios:

# %%
df_csv
# Out:
#                                         id  edad     genero  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0  Masculino
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0  Masculino
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN   Femenino
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0  Masculino
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0   Femenino
# ...                                    ...   ...        ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0   Femenino
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0  Masculino
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0  Masculino
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0   Femenino
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0  Masculino
#
#                     estado   IMC
# 0                  Florida  26.7
# 1                 Illinois  30.6
# 2                   Hawaii  26.7
# 3               California  29.2
# 4                     Utah  27.5
# ...                    ...   ...
# 999             California  25.7
# 1000             Louisiana  25.4
# 1001  District of Columbia  26.4
# 1002               Florida  18.3
# 1003              New York  24.5
#
# [1004 rows x 5 columns]

# %% [markdown]
# ### 5.4. Agregar columnas
#
# Y también podemos agregar columnas a un DataFrame. Por ejemplo agreguemos una columna para indicar si la persona tiene o no sobrepeso:

# %%
df_csv['soprepeso'] = 'No'
df_csv
# Out:
#                                         id  edad     genero  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0  Masculino
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0  Masculino
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN   Femenino
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0  Masculino
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0   Femenino
# ...                                    ...   ...        ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0   Femenino
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0  Masculino
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0  Masculino
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0   Femenino
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0  Masculino
#
#                     estado   IMC soprepeso
# 0                  Florida  26.7        No
# 1                 Illinois  30.6        No
# 2                   Hawaii  26.7        No
# 3               California  29.2        No
# 4                     Utah  27.5        No
# ...                    ...   ...       ...
# 999             California  25.7        No
# 1000             Louisiana  25.4        No
# 1001  District of Columbia  26.4        No
# 1002               Florida  18.3        No
# 1003              New York  24.5        No
#
# [1004 rows x 6 columns]

# %% [markdown]
# Y ahora usemos condicionales para rellenar esta columna indicando "Sí" si la persona tiene un IMC>25:

# %%
df_csv.loc[df_csv['IMC']>25, 'sobrepeso'] = 'Sí'
df_csv
# Out:
#                                         id  edad     genero  \
# 0     6c7984c9-270d-4dee-b21e-8460ba65a683  75.0  Masculino
# 1     45b54530-317e-4c64-b718-597990ff6fd9  84.0  Masculino
# 2     87ef46d9-e9c8-4ba3-8965-5553b48ad2d9   NaN   Femenino
# 3     33267565-7115-4bec-9dc1-3e5057412d10  57.0  Masculino
# 4     3cddc250-e992-4a30-8097-f1422761b7be  59.0   Femenino
# ...                                    ...   ...        ...
# 999   2c54f71c-23f8-46e6-abdf-05fc78e717a3  49.0   Femenino
# 1000  02568917-9a13-4f6b-ba09-5d664e8069f6  34.0  Masculino
# 1001  7ddaf233-2a46-429a-b4be-f8ff5917d299  47.0  Masculino
# 1002  889d5238-aa0c-4717-b841-962d09eeca9c  76.0   Femenino
# 1003  bacda779-4383-435c-a9d9-c8c8c5b28bd7  57.0  Masculino
#
#                     estado   IMC soprepeso sobrepeso
# 0                  Florida  26.7        No        Sí
# 1                 Illinois  30.6        No        Sí
# 2                   Hawaii  26.7        No        Sí
# 3               California  29.2        No        Sí
# 4                     Utah  27.5        No        Sí
# ...                    ...   ...       ...       ...
# 999             California  25.7        No        Sí
# 1000             Louisiana  25.4        No        Sí
# 1001  District of Columbia  26.4        No        Sí
# 1002               Florida  18.3        No       NaN
# 1003              New York  24.5        No       NaN
#
# [1004 rows x 7 columns]

# %% [markdown]
# ## 6. Agrupaciones
#
# El método "Groupby" resulta muy útil cuando queremos usar una variable categórica para generar agrupaciones.
#
# La sintaxis básica es:
#
# **DataFrame -> groupby -> función de agregación**
#
# Donde la *función de agregación* permite, como su nombre lo indica, agregar los valores de cada agrupación generada (por ejemplo sumándolos, promediándolos, etc.).
#
# Por ejemplo, generemos agrupaciones usando como criterio el estado y por cada estado calculemos el IMC promedio:

# %%
df_csv.groupby(['estado'])['IMC'].mean()
# Out:
# estado
# Alabama                 23.840000
# Alaska                  26.566667
# Arizona                 25.415789
# Arkansas                25.550000
# California              25.680412
# Colorado                23.592000
# Connecticut             24.942105
# Delaware                23.675000
# District of Columbia    24.700000
# Florida                 25.804286
# Georgia                 25.072727
# Hawaii                  25.966667
# Idaho                   26.175000
# Illinois                24.864706
# Indiana                 23.991667
# Iowa                    25.500000
# Kansas                  25.660000
# Kentucky                23.750000
# Louisiana               25.945455
# Maryland                26.127778
# Massachusetts           25.460000
# Michigan                26.100000
# Minnesota               25.100000
# Mississippi             22.650000
# Missouri                25.172222
# Montana                 28.650000
# Nebraska                22.940000
# Nevada                  25.660000
# New Hampshire           27.750000
# New Jersey              20.780000
# New Mexico              25.080000
# New York                24.560000
# North Carolina          25.828571
# North Dakota            23.840000
# Ohio                    24.766667
# Oklahoma                26.880000
# Oregon                  25.111111
# Pennsylvania            23.353846
# South Carolina          22.863636
# South Dakota            24.733333
# Tennessee               24.982353
# Texas                   24.963725
# Utah                    25.412500
# Virginia                24.676471
# Washington              24.537500
# West Virginia           25.344444
# Wisconsin               23.287500
# Name: IMC, dtype: float64

# %% [markdown]
# Y podemos organizar lo anterior por ejemplo de manera descendente por los valores promedios de IMC:

# %%
df_imc = df_csv.groupby(['estado'])['IMC'].mean().sort_values(ascending=False)
df_imc
# Out:
# estado
# Montana                 28.650000
# New Hampshire           27.750000
# Oklahoma                26.880000
# Alaska                  26.566667
# Idaho                   26.175000
# Maryland                26.127778
# Michigan                26.100000
# Hawaii                  25.966667
# Louisiana               25.945455
# North Carolina          25.828571
# Florida                 25.804286
# California              25.680412
# Kansas                  25.660000
# Nevada                  25.660000
# Arkansas                25.550000
# Iowa                    25.500000
# Massachusetts           25.460000
# Arizona                 25.415789
# Utah                    25.412500
# West Virginia           25.344444
# Missouri                25.172222
# Oregon                  25.111111
# Minnesota               25.100000
# New Mexico              25.080000
# Georgia                 25.072727
# Tennessee               24.982353
# Texas                   24.963725
# Connecticut             24.942105
# Illinois                24.864706
# Ohio                    24.766667
# South Dakota            24.733333
# District of Columbia    24.700000
# Virginia                24.676471
# New York                24.560000
# Washington              24.537500
# Indiana                 23.991667
# North Dakota            23.840000
# Alabama                 23.840000
# Kentucky                23.750000
# Delaware                23.675000
# Colorado                23.592000
# Pennsylvania            23.353846
# Wisconsin               23.287500
# Nebraska                22.940000
# South Carolina          22.863636
# Mississippi             22.650000
# New Jersey              20.780000
# Name: IMC, dtype: float64

# %% [markdown]
# ## 7. Almacenamiento de un DataFrame
#
# Y por último, podemos almacenar el DataFrame anterior por ejemplo como un archivo CSV:

# %%
df_imc.to_csv('/content/datos_IMC.csv')
